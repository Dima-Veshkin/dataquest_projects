# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets
#
# Our aim in this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. We're working as data analysts for a company that builds Android and iOS mobile apps, and our job is to enable our team of developers to make data-driven decisions with respect to the kind of apps they build.
#
# At our company, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.

# %% [markdown]
# Open and read dataset

# %%
from csv import reader


file_ios = open("AppleStore.csv", encoding="utf8")
read_cell_ios = reader(file_ios)
ios = list(read_cell_ios)
ios_header = ios[0]
ios = ios[1:]

file_android = open("googleplaystore.csv", encoding="utf8")
read_cell_android = reader(file_android)
android = list(read_cell_android)
android_header = android[0]
android = android[1:]

# %% [markdown]
# Create explore data function

# %%
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %% [markdown]
# Explore dataset iOS

# %%
explore_data(ios,0,3,True)
# Out:
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# Number of rows: 7197
# Number of columns: 16

# %% [markdown]
# Explore header of dataset iOS

# %%
print(ios_header)
# Out:
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']

# %% [markdown]
# Explore dataset Android

# %%
explore_data(android,0,3,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# Explore header of dataset Android

# %%
print(android_header)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# Delete wrong row in android dataset missing 'Rating'

# %%
del android[10472]

explore_data(android,0,0,True)
# Out:
# Number of rows: 10840
# Number of columns: 13

# %% [markdown]
# ## Removing Duplicate Entries

# %% [markdown]
# - Create a function to search for duplicates by name in our data
# - Find out the number of duplicates and unique applications in each dataset (Yes, iOS too. 2 duplicates it 2 duplicates)

# %%
def duplicate_data (data, index):
    duplicate_apps = []
    unique_apps = []
    for app in data:
        name = app[index]
        if name in unique_apps:
            duplicate_apps.append(name)
        else:
            unique_apps.append(name)
    return duplicate_apps


print('Number of Android apps:', len(android))
print('Number of duplicate Android apps:', len(duplicate_data(android,0)))
print('Number of unique Android apps:', len(android)-len(duplicate_data(android,0)))
print('\n')
print('Number of iOS apps:', len(ios))
print('Number of duplicate iOS apps:', len(duplicate_data(ios,1)))
print('Number of unique Android apps:', len(ios)-len(duplicate_data(ios,1)))
# Out:
# Number of Android apps: 10840
# Number of duplicate Android apps: 1181
# Number of unique Android apps: 9659
#
#
# Number of iOS apps: 7197
# Number of duplicate iOS apps: 2
# Number of unique Android apps: 7195

# %% [markdown]
# We don't remove the duplicates randomly. Criterion - rating
#
# - Create a function to search duplicates by name and max rating
# - For clear data we use criterion - rating. Do not forget that the data structure in Android and iOS is different.

# %%
def clear_dup_data (data, index1, index2):
    reviews_max = {}
    for app in data:
        name = app[index1]
        rating = float(app[index2])
        if name in reviews_max and reviews_max[name] < rating:
            reviews_max[name] = rating
        if name not in reviews_max:
            reviews_max[name] = rating
            
    clean = []
    added = []
    for app in data:
        name = app[index1]
        rating = float(app[index2])
        if (reviews_max[name] == rating) and (name not in added):
            clean.append(app)
            added.append(name)
    return clean

android = clear_dup_data(android,0,3)
print('Number of Android apps:', len(android))

ios = clear_dup_data(ios,1,5)
print('Number of iOS apps:', len(ios))
# Out:
# Number of Android apps: 9659
# Number of iOS apps: 7195

# %% [markdown]
# Now we have 2 new dataset and number of rows the same 'unique apps' as above

# %% [markdown]
# ### Removing Non-English Apps

# %%
print(ios[813][1])
print(ios[6731][1])

print(android[4412][0])
print(android[7940][0])
# Out:
# 爱奇艺PPS -《欢乐颂2》电视剧热播
# 激ムズ！和のひとふで書き！ 〜頭をつかう脳トレパズルゲーム〜
# 中国語 AQリスニング
# لعبة تقدر تربح DZ

# %% [markdown]
# Create funtion for search non-eng name apps

# %%
def is_eng (string):
    for c in string:
        if ord(c) > 127:
            return False
    
    return True

print(is_eng('Instagram'))
print(is_eng('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_eng('Docs To Go™ Free Office Suite'))
print(is_eng('Instachat 😜'))
# Out:
# True
# False
# False
# False

# %% [markdown]
# If the input string has more than three characters that fall outside the ASCII range (0 - 127), then the function return False (identify the string as non-English), otherwise it return True.

# %%
def is_eng (string):
    n = 0
    for c in string:
        if ord(c) > 127:
            n += 1
    
    if n > 3:
        return False
    else:
        return True

print(is_eng('Instagram'))
print(is_eng('爱奇艺PPS -《欢乐颂2》电视剧热播'))
print(is_eng('Docs To Go™ Free Office Suite'))
print(is_eng('Instachat 😜'))
# Out:
# True
# False
# True
# True

# %% [markdown]
# Below, we use the is_english() function to filter out the non-English apps for both data sets:

# %%
android_eng = []
ios_eng = []

for app in android:
    name = app[0]
    if is_eng(name):
        android_eng.append(app)
        
for app in ios:
    name = app[1]
    if is_eng(name):
        ios_eng.append(app)
        
explore_data(android_eng,0,2,True)
print('\n')
explore_data(ios_eng,0,2,True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 9614
# Number of columns: 13
#
#
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
#
# Number of rows: 6181
# Number of columns: 16

# %% [markdown]
# We can see that we're left with 9614 Android apps and 6181 iOS apps.

# %% [markdown]
# ### Isolate Free App

# %%
android_free = []
ios_free = []

for app in android_eng:
    price = app[7]
    if price == "0":
        android_free.append(app)

for app in ios_eng:
    price = app[4]
    if price == "0.0":
        ios_free.append(app)
        

android = clear_dup_data(android,0,3)
print('Number of Free Android apps:', len(android_free))

ios = clear_dup_data(ios,1,5)
print('Number of Free iOS apps:', len(ios_free))
# Out:
# Number of Free Android apps: 8864
# Number of Free iOS apps: 3220

# %% [markdown]
# ### Most Common Apps by Genre and Category

# %% [markdown]
# #### Part One
# Create display freq table function

# %%
def freq_table(data, index):
    total = 0
    table = {}
    
    for row in data:
        total += 1
        value = row[index]
        if value in table:
            table[value] += 1
        else:
            table[value] = 1
    
    total_perc = {}
    for element in table:
        total_perc[element] = (table[element]/total)*100
    return total_perc

def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        value = (table[key], key)
        table_display.append(value)
    
    table_sort = sorted(table_display,reverse = True)
    for entry in table_sort:
        print(entry[1],':',entry[0])

# %% [markdown]
# #### Part Two
# We start by examining the frequency table for the prime_genre column of the App Store data set.

# %%
display_table(ios_free,-5)
# Out:
# Games : 58.13664596273293
# Entertainment : 7.888198757763975
# Photo & Video : 4.968944099378882
# Education : 3.6645962732919255
# Social Networking : 3.291925465838509
# Shopping : 2.608695652173913
# Utilities : 2.515527950310559
# Sports : 2.142857142857143
# Music : 2.049689440993789
# Health & Fitness : 2.018633540372671
# Productivity : 1.7391304347826086
# Lifestyle : 1.5838509316770186
# News : 1.3354037267080745
# Travel : 1.2422360248447204
# Finance : 1.1180124223602486
# Weather : 0.8695652173913043
# Food & Drink : 0.8074534161490683
# Reference : 0.5590062111801243
# Business : 0.5279503105590062
# Book : 0.43478260869565216
# Navigation : 0.18633540372670807
# Medical : 0.18633540372670807
# Catalogs : 0.12422360248447205

# %% [markdown]
# The general impression is that App Store is dominated by apps that are designed for fun, while apps with practical purposes are more rare
#
# However, the fact that fun apps are the most numerous doesn't also imply that they also have the greatest number of users — the demand might not be the same as the offer.
#
# Examining the Genres and Category columns of the Google Play data set (two columns which seem to be related).

# %%
display_table(android_free,1)
# Out:
# FAMILY : 18.907942238267147
# GAME : 9.724729241877256
# TOOLS : 8.461191335740072
# BUSINESS : 4.591606498194946
# LIFESTYLE : 3.9034296028880866
# PRODUCTIVITY : 3.892148014440433
# FINANCE : 3.7003610108303246
# MEDICAL : 3.531137184115524
# SPORTS : 3.395758122743682
# PERSONALIZATION : 3.3167870036101084
# COMMUNICATION : 3.2378158844765346
# HEALTH_AND_FITNESS : 3.0798736462093865
# PHOTOGRAPHY : 2.944494584837545
# NEWS_AND_MAGAZINES : 2.7978339350180503
# SOCIAL : 2.6624548736462095
# TRAVEL_AND_LOCAL : 2.33528880866426
# SHOPPING : 2.2450361010830324
# BOOKS_AND_REFERENCE : 2.1435018050541514
# DATING : 1.861462093862816
# VIDEO_PLAYERS : 1.7937725631768955
# MAPS_AND_NAVIGATION : 1.3989169675090252
# FOOD_AND_DRINK : 1.2409747292418771
# EDUCATION : 1.1620036101083033
# ENTERTAINMENT : 0.9589350180505415
# LIBRARIES_AND_DEMO : 0.9363718411552346
# AUTO_AND_VEHICLES : 0.9250902527075812
# HOUSE_AND_HOME : 0.8235559566787004
# WEATHER : 0.8009927797833934
# EVENTS : 0.7107400722021661
# PARENTING : 0.6543321299638989
# ART_AND_DESIGN : 0.6430505415162455
# COMICS : 0.6204873646209386
# BEAUTY : 0.5979241877256317

# %% [markdown]
# The landscape seems significantly different on Google Play: there are not that many apps designed for fun, and it seems that a good number of apps are designed for practical purposes (family, tools, business, lifestyle, productivity, etc.). However, if we investigate this further, we can see that the family category (which accounts for almost 19% of the apps) means mostly games for kids.

# %%
display_table(android_free,9)
# Out:
# Tools : 8.449909747292418
# Entertainment : 6.069494584837545
# Education : 5.347472924187725
# Business : 4.591606498194946
# Productivity : 3.892148014440433
# Lifestyle : 3.892148014440433
# Finance : 3.7003610108303246
# Medical : 3.531137184115524
# Sports : 3.463447653429603
# Personalization : 3.3167870036101084
# Communication : 3.2378158844765346
# Action : 3.1024368231046933
# Health & Fitness : 3.0798736462093865
# Photography : 2.944494584837545
# News & Magazines : 2.7978339350180503
# Social : 2.6624548736462095
# Travel & Local : 2.3240072202166067
# Shopping : 2.2450361010830324
# Books & Reference : 2.1435018050541514
# Simulation : 2.0419675090252705
# Dating : 1.861462093862816
# Arcade : 1.8501805054151623
# Video Players & Editors : 1.7712093862815883
# Casual : 1.7599277978339352
# Maps & Navigation : 1.3989169675090252
# Food & Drink : 1.2409747292418771
# Puzzle : 1.128158844765343
# Racing : 0.9927797833935018
# Role Playing : 0.9363718411552346
# Libraries & Demo : 0.9363718411552346
# Auto & Vehicles : 0.9250902527075812
# Strategy : 0.9138086642599278
# House & Home : 0.8235559566787004
# Weather : 0.8009927797833934
# Events : 0.7107400722021661
# Adventure : 0.6768953068592057
# Comics : 0.6092057761732852
# Beauty : 0.5979241877256317
# Art & Design : 0.5979241877256317
# Parenting : 0.4963898916967509
# Card : 0.45126353790613716
# Casino : 0.42870036101083037
# Trivia : 0.41741877256317694
# Educational;Education : 0.39485559566787
# Board : 0.3835740072202166
# Educational : 0.3722924187725632
# Education;Education : 0.33844765342960287
# Word : 0.2594765342960289
# Casual;Pretend Play : 0.236913357400722
# Music : 0.2030685920577617
# Racing;Action & Adventure : 0.16922382671480143
# Puzzle;Brain Games : 0.16922382671480143
# Entertainment;Music & Video : 0.16922382671480143
# Casual;Brain Games : 0.13537906137184114
# Casual;Action & Adventure : 0.13537906137184114
# Arcade;Action & Adventure : 0.12409747292418773
# Action;Action & Adventure : 0.10153429602888085
# Educational;Pretend Play : 0.09025270758122744
# Simulation;Action & Adventure : 0.078971119133574
# Parenting;Education : 0.078971119133574
# Entertainment;Brain Games : 0.078971119133574
# Board;Brain Games : 0.078971119133574
# Parenting;Music & Video : 0.06768953068592057
# Educational;Brain Games : 0.06768953068592057
# Casual;Creativity : 0.06768953068592057
# Art & Design;Creativity : 0.06768953068592057
# Education;Pretend Play : 0.056407942238267145
# Role Playing;Pretend Play : 0.04512635379061372
# Education;Creativity : 0.04512635379061372
# Role Playing;Action & Adventure : 0.033844765342960284
# Puzzle;Action & Adventure : 0.033844765342960284
# Entertainment;Creativity : 0.033844765342960284
# Entertainment;Action & Adventure : 0.033844765342960284
# Educational;Creativity : 0.033844765342960284
# Educational;Action & Adventure : 0.033844765342960284
# Education;Music & Video : 0.033844765342960284
# Education;Brain Games : 0.033844765342960284
# Education;Action & Adventure : 0.033844765342960284
# Adventure;Action & Adventure : 0.033844765342960284
# Video Players & Editors;Music & Video : 0.02256317689530686
# Sports;Action & Adventure : 0.02256317689530686
# Simulation;Pretend Play : 0.02256317689530686
# Puzzle;Creativity : 0.02256317689530686
# Music;Music & Video : 0.02256317689530686
# Entertainment;Pretend Play : 0.02256317689530686
# Casual;Education : 0.02256317689530686
# Board;Action & Adventure : 0.02256317689530686
# Video Players & Editors;Creativity : 0.01128158844765343
# Trivia;Education : 0.01128158844765343
# Travel & Local;Action & Adventure : 0.01128158844765343
# Tools;Education : 0.01128158844765343
# Strategy;Education : 0.01128158844765343
# Strategy;Creativity : 0.01128158844765343
# Strategy;Action & Adventure : 0.01128158844765343
# Simulation;Education : 0.01128158844765343
# Role Playing;Brain Games : 0.01128158844765343
# Racing;Pretend Play : 0.01128158844765343
# Puzzle;Education : 0.01128158844765343
# Parenting;Brain Games : 0.01128158844765343
# Music & Audio;Music & Video : 0.01128158844765343
# Lifestyle;Pretend Play : 0.01128158844765343
# Lifestyle;Education : 0.01128158844765343
# Health & Fitness;Education : 0.01128158844765343
# Health & Fitness;Action & Adventure : 0.01128158844765343
# Entertainment;Education : 0.01128158844765343
# Communication;Creativity : 0.01128158844765343
# Comics;Creativity : 0.01128158844765343
# Casual;Music & Video : 0.01128158844765343
# Card;Action & Adventure : 0.01128158844765343
# Books & Reference;Education : 0.01128158844765343
# Art & Design;Pretend Play : 0.01128158844765343
# Art & Design;Action & Adventure : 0.01128158844765343
# Arcade;Pretend Play : 0.01128158844765343
# Adventure;Education : 0.01128158844765343

# %% [markdown]
# The difference between the Genres and the Category columns is not crystal clear, but one thing we can notice is that the Genres column is much more granular (it has more categories). We're only looking for the bigger picture at the moment, so we'll only work with the Category column moving forward.

# %% [markdown]
# ### Most Popular Apps by Genre on the App Store

# %% [markdown]
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. For the Google Play data set, we can find this information in the Installs column, but for the App Store data set this information is missing. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the rating_count_tot app.

# %%
genres_ios = freq_table(ios_free, -5)

for genre in genres_ios:
    total = 0
    len_genre = 0
    for app in ios_free:
        genre_app = app[-5]
        if genre_app == genre:
            rat = float(app[5])
            total += rat
            len_genre += 1
    avg_rat = total/len_genre
    print(genre,':',round(avg_rat,2))
# Out:
# Social Networking : 71548.35
# Photo & Video : 28441.54
# Games : 22812.92
# Music : 57326.53
# Reference : 74942.11
# Health & Fitness : 23298.02
# Weather : 52279.89
# Utilities : 18684.46
# Travel : 28243.8
# Shopping : 26919.69
# News : 21248.02
# Navigation : 86090.33
# Lifestyle : 16485.76
# Entertainment : 14029.83
# Food & Drink : 33333.92
# Sports : 23008.9
# Book : 39758.5
# Finance : 31467.94
# Education : 7003.98
# Productivity : 21028.41
# Business : 7491.12
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# Navigation, Social Network, Photo&Video, Music have good average number because the have few giants like Google Maps, Facebook, Pinterest, Skype, Pandora, Spotify, Shazam.

# %%
for app in ios_free:
    if app[-5] == 'Reference':
        print(app[1], ':', app[5])
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0

# %% [markdown]
# ### Most Popular Apps by Genre on Google Play

# %% [markdown]
# For the Google Play market, we actually have data about the number of installs, but its open-ended (100+, 1,000+, 5,000+, etc.):

# %%
display_table(android_free,5)
# Out:
# 1,000,000+ : 15.726534296028879
# 100,000+ : 11.552346570397113
# 10,000,000+ : 10.548285198555957
# 10,000+ : 10.198555956678701
# 1,000+ : 8.393501805054152
# 100+ : 6.915613718411552
# 5,000,000+ : 6.825361010830325
# 500,000+ : 5.561823104693141
# 50,000+ : 4.7721119133574
# 5,000+ : 4.512635379061372
# 10+ : 3.5424187725631766
# 500+ : 3.2490974729241873
# 50,000,000+ : 2.3014440433213
# 100,000,000+ : 2.1322202166064983
# 50+ : 1.917870036101083
# 5+ : 0.78971119133574
# 1+ : 0.5076714801444043
# 500,000,000+ : 0.2707581227436823
# 1,000,000,000+ : 0.22563176895306858
# 0+ : 0.04512635379061372
# 0 : 0.01128158844765343

# %%
table = freq_table(android_free,1)
table_sort = []

for category in table:
    total = 0
    len_category = 0
    for app in android_free:
        category_app = app[1]
        if category_app == category:
            installs = app[5]
            installs = installs.replace(',','')
            installs = installs.replace('+','')
            total += float(installs)
            len_category += 1
    avg_installs = total / len_category
    cat_inst = (category, int(avg_installs))
    table_sort.append(cat_inst)

table_sort = sorted(table_sort, reverse = True, key = lambda t: t[1])
for row in table_sort:
    print(row[0],":",row[1])
# Out:
# COMMUNICATION : 38456119
# VIDEO_PLAYERS : 24727872
# SOCIAL : 23253652
# PHOTOGRAPHY : 17840110
# PRODUCTIVITY : 16787331
# GAME : 15588015
# TRAVEL_AND_LOCAL : 13984077
# ENTERTAINMENT : 11640705
# TOOLS : 10801391
# NEWS_AND_MAGAZINES : 9549178
# BOOKS_AND_REFERENCE : 8767811
# SHOPPING : 7036877
# PERSONALIZATION : 5201482
# WEATHER : 5074486
# HEALTH_AND_FITNESS : 4188821
# MAPS_AND_NAVIGATION : 4056941
# FAMILY : 3695641
# SPORTS : 3638640
# ART_AND_DESIGN : 1986335
# FOOD_AND_DRINK : 1924897
# EDUCATION : 1833495
# BUSINESS : 1712290
# LIFESTYLE : 1437816
# FINANCE : 1387692
# HOUSE_AND_HOME : 1331540
# DATING : 854028
# COMICS : 817657
# AUTO_AND_VEHICLES : 647317
# LIBRARIES_AND_DEMO : 638503
# PARENTING : 542603
# BEAUTY : 513151
# EVENTS : 253542
# MEDICAL : 120550

# %% [markdown]
# On average, communication apps have the most installs: 38,456,119. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs:

# %%
for app in android_free:
    if app[1] == 'TOOLS' and (app[5] == '1,000,000,000+'
                                      or app[5] == '500,000,000+'
                                      or app[5] == '100,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Google : 1,000,000,000+
# Google Translate : 500,000,000+
# Calculator : 100,000,000+
# Device Help : 100,000,000+
# Account Manager : 100,000,000+
# SHAREit - Transfer & Share : 500,000,000+
# Samsung Calculator : 100,000,000+
# Gboard - the Google Keyboard : 500,000,000+
# Google Korean Input : 100,000,000+
# Share Music & Transfer Files - Xender : 100,000,000+
# Tiny Flashlight + LED : 100,000,000+
# GO Keyboard - Cute Emojis, Themes and GIFs : 100,000,000+
# Speedtest by Ookla : 100,000,000+
# CM Locker - Security Lockscreen : 100,000,000+
# Applock : 100,000,000+
# Clean Master- Space Cleaner & Antivirus : 500,000,000+
# Lookout Security & Antivirus : 100,000,000+
# Google Now Launcher : 100,000,000+
# 360 Security - Free Antivirus, Booster, Cleaner : 100,000,000+
# Samsung Smart Switch Mobile : 100,000,000+
# Avast Mobile Security 2018 - Antivirus & App Lock : 100,000,000+
# AppLock : 100,000,000+
# AVG AntiVirus 2018 for Android Security : 100,000,000+
# Security Master - Antivirus, VPN, AppLock, Booster : 500,000,000+
# Battery Doctor-Battery Life Saver & Battery Cooler : 100,000,000+
# Automatic Call Recorder : 100,000,000+
# Anti-virus Dr.Web Light : 100,000,000+
# Cache Cleaner-DU Speed Booster (booster & cleaner) : 100,000,000+
# DU Battery Saver - Battery Charger & Battery Life : 100,000,000+

# %% [markdown]
# If we removed all the communication apps that have over 100 million installs, the average would be reduced roughly ten times:

# %%
for app in android_free:
    if app[1] == 'TOOLS':
        print(app[0], ':', app[5])
# Out:
# Google : 1,000,000,000+
# Google Translate : 500,000,000+
# Moto Display : 10,000,000+
# Motorola Alert : 50,000,000+
# Motorola Assist : 50,000,000+
# Moto Suggestions ™ : 1,000,000+
# Moto Voice : 10,000,000+
# Calculator : 100,000,000+
# Device Help : 100,000,000+
# Account Manager : 100,000,000+
# myMetro : 10,000,000+
# File Manager : 50,000,000+
# My Telcel : 50,000,000+
# Calculator - free calculator, multi calculator app : 10,000,000+
# ASUS Sound Recorder : 10,000,000+
# iWnn IME for Nexus : 5,000,000+
# Samsung Max - Data Savings & Privacy Protection : 10,000,000+
# Android TV Remote Service : 1,000,000+
# ZenUI Help : 10,000,000+
# Calculator - free calculator ,multi calculator app : 100,000+
# SHAREit - Transfer & Share : 500,000,000+
# ZenUI Keyboard – Emoji, Theme : 10,000,000+
# Files Go by Google: Free up space on your phone : 10,000,000+
# SD card backup : 1,000,000+
# Nokia mobile support : 5,000,000+
# File Manager -- Take Command of Your Files Easily : 10,000,000+
# Samsung Calculator : 100,000,000+
# Clear : 10,000,000+
# Phone : 10,000,000+
# HTC Lock Screen : 10,000,000+
# Gboard - the Google Keyboard : 500,000,000+
# Google Korean Input : 100,000,000+
# AT&T Smart Wi-Fi : 10,000,000+
# Google app for Android TV : 10,000,000+
# Sound Recorder: Recorder & Voice Changer Free : 10,000,000+
# Remote Link (PC Remote) : 10,000,000+
# HTC Sense Input : 10,000,000+
# Share Music & Transfer Files - Xender : 100,000,000+
# App vault : 10,000,000+
# TouchPal Keyboard for vivo : 1,000,000+
# Google Assistant Go : 500,000+
# My love : 10,000,000+
# DuraSpeed : 10,000,000+
# HTC Sense Input-LV : 50,000+
# HTC Sense Input-CA : 100,000+
# HTC Sense Input-AR : 100,000+
# Digital Alarm Clock : 10,000,000+
# Alarm Clock Free : 10,000,000+
# Puzzle Alarm Clock ⏰ : 1,000,000+
# Alarm Clock : 5,000,000+
# I Can't Wake Up! Alarm Clock : 1,000,000+
# High-Powered Flashlight : 10,000,000+
# Brightest Flashlight - LED Light : 50,000,000+
# LED Flashlight : 10,000,000+
# Tiny Flashlight + LED : 100,000,000+
# Flashlight & LED Torch : 10,000,000+
# Color Flashlight : 50,000,000+
# CM Flashlight (Compass, SOS) : 5,000,000+
# Flashlight HD LED : 50,000,000+
# Flashlight - Torch LED Light : 10,000,000+
# Super Flashlight + LED : 5,000,000+
# Brightest LED Flashlight : 5,000,000+
# Brightest Flashlight Free ® : 50,000,000+
# Fraction Calculator Plus Free : 5,000,000+
# Calculator Plus Free : 10,000,000+
# CALCU™ Stylish Calculator Free : 5,000,000+
# Mobi Calculator free & AD free! : 5,000,000+
# Calculator with Percent (Free) : 1,000,000+
# Graphing Calculator : 1,000,000+
# Unit Converter : 1,000,000+
# Calculator ++ : 1,000,000+
# MyScript Calculator : 10,000,000+
# ConvertPad - Unit Converter : 10,000,000+
# Unit Converter Pro : 1,000,000+
# Classic Calculator : 5,000,000+
# Scientific Calculator Free : 1,000,000+
# weight conversion calculator : 100,000+
# Age Calculator : 1,000,000+
# EzCalculator : 100,000+
# SuperVPN Free VPN Client : 50,000,000+
# Hideman VPN : 5,000,000+
# Fast Secure VPN : 1,000,000+
# Free & Premium VPN - FinchVPN : 1,000,000+
# Hotspot Shield Free VPN Proxy & Wi-Fi Security : 50,000,000+
# OpenVPN Connect – Fast & Safe SSL VPN Client : 10,000,000+
# VPN - Fast, Secure & Unlimited WiFi with VyprVPN : 1,000,000+
# FREEDOME VPN Unlimited anonymous Wifi Security : 1,000,000+
# SurfEasy Secure Android VPN : 5,000,000+
# TunnelBear VPN : 5,000,000+
# VPN Free - Betternet Hotspot VPN & Private Browser : 10,000,000+
# Smart Keyboard Trial : 10,000,000+
# Emoji keyboard - Cute Emoticons, GIF, Stickers : 50,000,000+
# GO Keyboard - Cute Emojis, Themes and GIFs : 100,000,000+
# Google Handwriting Input : 10,000,000+
# Wifi Analyzer : 10,000,000+
# Network Signal Info : 1,000,000+
# Speedtest by Ookla : 100,000,000+
# osmino Wi-Fi: free WiFi : 10,000,000+
# WiFi Overview 360 : 1,000,000+
# Speedcheck : 1,000,000+
# Internet Speed Meter Lite : 10,000,000+
# Wifi Inspector : 5,000,000+
# WiFi Automatic : 1,000,000+
# NETGEAR WiFi Analytics : 1,000,000+
# Keypad Lock Screen : 10,000,000+
# photo keypad lockscreen : 10,000,000+
# CM Locker - Security Lockscreen : 100,000,000+
# Solo Locker (DIY Locker) : 10,000,000+
# Lock Screen : 1,000,000+
# ZERO Lock Screen : 1,000,000+
# AppLock - Fingerprint : 10,000,000+
# Applock : 100,000,000+
# Smart AppLock (App Protect) : 10,000,000+
# Screen Off and Lock : 10,000,000+
# Screen Lock : 1,000,000+
# Flashlight : 10,000,000+
# B-BLE(BLE4.0 Scan) : 10,000+
# Servers Ultimate Pack B : 50,000+
# Clean Master- Space Cleaner & Antivirus : 500,000,000+
# Bridge-C - Get More Storage : 1,000+
# Screen Lock - with Fingerprint Simulator : 10,000,000+
# Tuner - gStrings Free : 10,000,000+
# Lookout Security & Antivirus : 100,000,000+
# Video Downloader for Facebook : 50,000,000+
# FlashLight F.Light : 100,000+
# F-Secure SENSE : 5,000+
# F-Secure KEY Password manager : 100,000+
# F-Secure SAFE : 500,000+
# F-Secure AV Test : 50,000+
# F-Secure Mobile Security : 500,000+
# F : 500+
# Convert degree Celsius to Fahrenheit or °F to °C : 5,000+
# Google Now Launcher : 100,000,000+
# Speedometer with G-FORCE meter : 50,000+
# Car G-Force Meter : 10,000+
# HSPA+ Tweaker (3G booster) : 5,000,000+
# DNS Changer - BEST (Gprs/Edge/3G/H/H+/4G) : 5,000+
# Force LTE Only : 1,000,000+
# Mobile Number Tracker : 5,000,000+
# I Screen Dialer : 1,000,000+
# J Touch : 100,000+
# Smart TV Remote : 10,000,000+
# K keyboard - Myanmar : 100,000+
# K-Chiing VPN (Free) : 5,000+
# 360-M Flight : 10,000+
# GTS-M : 5,000+
# M Notifier for M Launcher : 100,000+
# O Launcher 8.0 for Android™ O Oreo Launcher : 1,000,000+
# AC Remote for O General - NOW FREE : 50,000+
# O Launcher : 100,000+
# O Multiple - App Cloner, Duals APP, tarallel : 50,000+
# Super P Launcher for Android P 9.0 launcher, theme : 100,000+
# P9 Launcher - Android™ 9.0 P Launcher Style : 100,000+
# Android P Rotation : 10,000+
# Android P Launcher 9.0 launcher : 10,000+
# Q-See QC View : 100,000+
# Q Remote Control : 500,000+
# myQ : 100,000+
# QR Code Reader : 50,000,000+
# Q Call : 1,000+
# Q-See QT View : 100,000+
# .R : 10,000+
# R File Manager : 50+
# 360 Security - Free Antivirus, Booster, Cleaner : 100,000,000+
# S Player - Lightest and Most Powerful Video Player : 1,000,000+
# Samsung Smart Switch Mobile : 100,000,000+
# S S9 Launcher - Galaxy S8/S9 Launcher, theme, cool : 1,000,000+
# S Pen Keeper : 50,000+
# T-Mobile : 10,000,000+
# T-Mobile Visual Voicemail : 50,000,000+
# AT&T FamilyMap® : 10,000,000+
# Don't touch my phone : 5,000,000+
# U-Scan : 50,000+
# Parallel U - App Cloner, Duals APP, tarallel : 500,000+
# U get - Wireless Speed Test : 5,000+
# U Guard : 10,000+
# Remote For ATT U-verse TV - NOW FREE : 5,000+
# Ace Screen Recorder w facecam : 100,000+
# WIFI WPS WPA TESTER : 10,000,000+
# Flashlight Free w/ compass : 10,000+
# App Lock: Locker w/ fingerprint, Parental Control : 1,000,000+
# Open in WhatsApp (click to chat) : 1,000,000+
# WPSApp : 10,000,000+
# X-VPN - Free Unlimited VPN Proxy : 5,000,000+
# Phone X Launcher, OS 11 iLauncher & Control Center : 5,000,000+
# Lock Screen Phone X Style OS 11 : 100,000+
# Control Center iOS 11 - Phone X Control Panel : 100,000+
# X-plore File Manager : 10,000,000+
# Flashlight X : 1,000,000+
# iSwipe Phone X : 1,000,000+
# X Home Bar - Free : 100,000+
# [ROOT] X Privacy Installer : 1,000,000+
# Control Center iOS 11 - Phone X notifications : 50,000+
# Antivirus & Mobile Security : 10,000,000+
# Flashlight Ultimate : 1,000,000+
# Avast Mobile Security 2018 - Antivirus & App Lock : 100,000,000+
# ZArchiver : 10,000,000+
# Zapya - File Transfer, Sharing : 10,000,000+
# CPU-Z : 10,000,000+
# Moto Z Market : 1,000,000+
# AB Screen Recorder : 10,000+
# Universal AC Remote Control : 1,000,000+
# Smart Air Conditioner : 500,000+
# AC Remote Control : 100,000+
# Air conditioner remote control : 1,000,000+
# AC WIFI : 10,000+
# A/C Air Conditioner Remote : 1,000,000+
# Smart Air Conditioner(CAC) : 50,000+
# Carrier Air Conditioner : 100,000+
# AC Troubleshooter : 10,000+
# TOSHIBA Smart AC : 10,000+
# Trane Interactive Smart AC : 10,000+
# AC remote control mobile : 100,000+
# AC Remote for Haier - NOW FREE : 50,000+
# AC Remote for Daikin - NOW FREE : 50,000+
# A/C Universal Remote Control : 1,000,000+
# AC Remote for LG - NOW FREE : 100,000+
# Plug-in app (System AC) : 10,000+
# AC Remote for Midea - NOW FREE : 100,000+
# Ac remote control : 50,000+
# Mi Remote controller - for TV, STB, AC and more : 10,000,000+
# AC Remote For LG : 100,000+
# Hi-Smart AC : 1,000+
# AC Remote for Sharp - NOW FREE : 50,000+
# AC Remote for Samsung - NOW FREE : 100,000+
# AC Remote for Carrier - NOW FREE : 10,000+
# AC & TV, DVD, Set Top Box - Remote control IR : 1,000,000+
# ac remote control : 500,000+
# AppBrain Ad Detector : 1,000,000+
# AdClear Ad blocker for Samsung : 500,000+
# Adguard Content Blocker : 1,000,000+
# Ad Detector : 50,000+
# Anti Adware : 1,000,000+
# Ad Block REMOVER - NEED ROOT : 100,000+
# Photo Compress 2.0 - Ad Free : 1,000,000+
# Emo Ads Blocker Browser : 100,000+
# Apps Ads Detector : 100,000+
# AE Order : 1,000+
# AE Manager : 100+
# AppFinder by AppTap : 5,000,000+
# DSLR Blur Camera Auto Focus : 10,000+
# AppLock : 100,000,000+
# Ag Tools : 1,000+
# AG Screen Recorder : 1,000+
# SOLEM AG : 1,000+
# BRL AG : 100+
# AG test : 100+
# AG Track : 100+
# WoW AH Tracker : 10,000+
# Cathy AH : 1+
# SMS AI Bot : 10,000+
# Ai File Viewer : 10,000+
# ParaTek Ai Speech generator : 50,000+
# AI Benchmark : 5,000+
# Virtual Eye AI : 500+
# AK47 Assault Rifle : 10,000+
# AK Booster : 10,000+
# Where Am I? : 100,000+
# A. O. Smith : 10,000+
# AP Manager : 10,000+
# Access Point Browser : 1,000+
# AP Installer : 5,000+
# Access Point Proximity : 1,000+
# UniFi : 500,000+
# Ap Video Downloader for fb New 2018 : 100,000+
# HotSpot Tethering Free/WiFi AP : 100,000+
# Fate GO Ap Counter : 1,000+
# APN Settings : 1,000,000+
# AQ wisdom + : 100+
# AQ SMS Notify : 10+
# QR BARCODE SCANNER : 10,000,000+
# ARuler - AR Ruler app, Measure tools : 100,000+
# Image 2 Wallpaper : 5,000,000+
# Powershop AU : 10,000+
# AVG AntiVirus 2018 for Android Security : 100,000,000+
# AV Tools : 100,000+
# Remote for Onkyo AV Receivers & Smart TV/Blu-Ray : 100,000+
# LG AV REMOTE : 1,000,000+
# Norton Security and Antivirus : 10,000,000+
# Remote For Pioneer AV Receivers and Blu-Ray : 50,000+
# Kaspersky Mobile Antivirus: AppLock & Web Security : 50,000,000+
# Samsung TV AV Guide 2016 : 5,000+
# Bitdefender Antivirus Free : 1,000,000+
# Avast Cleanup & Boost, Phone Cleaner, Optimizer : 10,000,000+
# Analog Clock AW Plus-7 : 100,000+
# Analog Clock AW-7 : 100,000+
# Watch AW-7 : 50,000+
# Digital Clock AW-7 : 100,000+
# Analog and Digital Clock AW-7 : 50,000+
# AW CAMERA : 100+
# AW Browser with Chrome Custom Tabs : 500+
# Roman Clock AW-7 : 5,000+
# Square Analog Clock AW-7 : 50,000+
# Axxess AX-DSP : 5,000+
# AX Window : 5+
# Axxess Updater : 10,000+
# AX-PIC Pedidos : 1,000+
# AY Recorder - Screen Recorder, Live, Video Editor : 500+
# Ay Yıldız Keyboard : 1,000+
# Display Phone Screen On TV : 1,000,000+
# AZ Screen Recorder pro : 5,000+
# AZ PLAYER HD : 10,000+
# AZ REMOTE CONTROL : 50,000+
# Loreal - BA Makeup : 1,000+
# Elif Ba Oyunu : 5,000+
# BC Wildfire : 5,000+
# BD tools : 10,000+
# Remote for Samsung TV & BluRay Players (Read Desc) : 500,000+
# Vehicle Case Checker BD : 10,000+
# Remote for Sony TV & Sony Blu-Ray Players MyAV : 1,000,000+
# Remote for Panasonic TV+BD+AVR : 100,000+
# Unseen - No Last Seen : 5,000,000+
# BF-Calc : 100,000+
# BG Advisor™ : 1,000+
# HTC Sense Input-BG : 100,000+
# HTC Sense Input - BG : 10,000+
# ReactNative BG Geolocation : 1,000+
# Simple Photo BG Changer : 10+
# BG Remover & Eraser Pro : 500+
# BG-FLEET : 10+
# Bg+ Call Blocker : 10,000+
# ScorePal : 10,000+
# GEM™ : 500+
# VIVA BH : 100,000+
# bi-Cube Mobile Token : 1,000+
# All Language Translator : 5,000,000+
# Virtual DJ Sound Mixer : 500,000+
# Metal Detector Pro 2015 : 100,000+
# BK Formula Calculator 2 : 100+
# Service Disabler : 100,000+
# BK Formula Calculator : 100+
# K-Rain BL : 1,000+
# BM Online OEC Verification : 100,000+
# TuenMun BM : 1,000+
# BM speed test : 10+
# Sam.BN : 1,000+
# BP Assist : 100+
# BQ Services : 1,000,000+
# BQ Scan : 100+
# Software Update : 1,000,000+
# BQ Scanner : 100+
# System Update Free : 100,000+
# Free antivirus and VPN : 1,000,000+
# Simple Gallery : 1,000,000+
# Zetup, print in one click : 1,000+
# Next Portuguese(BR) Langpack : 100,000+
# BS Battery+ : 50,000+
# BS Where Am I : 50+
# BS TRACK CLIENT : 10+
# CABLE SIZE CALCULATOR BS 7671 : 100,000+
# VOLT DROP CALCULATOR BS 7671 : 10,000+
# BTNotification : 5,000,000+
# Little Magnet BT : 100,000+
# BT Notifier : 1,000,000+
# Bt Notifier -Smartwatch notice : 500,000+
# ProGrade BT : 500+
# BT Controller : 1,000,000+
# Mediatek SmartDevice : 1,000,000+
# LG BT Reader Plus : 500,000+
# Bluetooth Control BT->uC FREE : 10,000+
# Autool BT-BOX : 500+
# BT Remote (SPP) for Bluetooth : 10,000+
# BT Satmeter : 100+
# Battery Notifier BT Free : 1,000,000+
# BT Position Sender - Bluetooth Position Sender : 10+
# OSRAM BT Control : 1,000+
# Jabbla BT : 100+
# SenseView BT Zephyr Sensor : 5,000+
# VictronConnect : 50,000+
# BW Smart : 5,000+
# BW SmartLife : 100+
# Bixby Button Remapper - bxActions : 1,000,000+
# Bx Access 4d : 100+
# QR & Barcode Scanner BX PRO : 1,000+
# LEDSHOWTW : 500+
# Limbo PC Emulator QEMU ARM x86 : 1,000,000+
# Project Fi by Google : 1,000,000+
# BZ Conferencing : 1,000+
# WISE- MOBILE PORTAL : 500+
# Putzmeister Experts : 1,000+
# Bubble : 5,000,000+
# CA Mobile OTP : 100,000+
# CA Auth ID : 10,000+
# CA DMV : 1,000,000+
# CB Frequencies FREE! : 100,000+
# Frequencies Free : 100,000+
# CBRadioTab : 50,000+
# CB SMART LIFE : 500+
# CB SmartCAR Monitor : 10+
# Antenna Tool : 50,000+
# CD View Lite : 100+
# Disc Label Print : 10,000+
# CD View : 500+
# РееI Smart Remote MP3 CD Player : 5,000+
# CE on the go : 10,000+
# CE Smart : 100+
# CCleaner : 50,000,000+
# Terminal Emulator for Android : 10,000,000+
# Ceasa CE : 50+
# CF.lumen : 100,000+
# CF-Bench : 100,000+
# iOBD2-CF : 500+
# CF cal : 10,000+
# CG Shikshak Mitan : 50,000+
# CG 3D Model Viewer: view 3D models interactively : 100+
# CG Wizard : 100+
# Bhunaksha CG : 10,000+
# gps tracker cg : 50+
# Green Build - An unofficial Travis CI client : 100+
# mySharpBranded CI Test : 1+
# Mesure CI : 500+
# CK Shop : 1,000+
# CL Reader for Craigslist(For sale, jobs, rental..) : 1,000+
# CL REPL : 1,000+
# CL Keyboard - Myanmar Keyboard (No Ads) : 5,000+
# CL Notifier : 100+
# MPS CL : 10+
# Turnotronik CL : 10+
# Security Master - Antivirus, VPN, AppLock, Booster : 500,000,000+
# Clean Master Lite - For Low-End Phone : 50,000,000+
# CM Security Open VPN - Free, fast unlimited proxy : 1,000,000+
# CM Security Lite - Antivirus : 10,000,000+
# CM Apps : 100,000+
# CM AppLock : 100,000+
# Ruler(cm, inch) : 500,000+
# AppLock - Fingerprint Unlock : 5,000,000+
# Battery Doctor-Battery Life Saver & Battery Cooler : 100,000,000+
# Speed Booster - Ram, Battery & Game Speed Booster : 1,000,000+
# CM FILE MANAGER : 50,000,000+
# Height Converter feet-inch cm : 100,000+
# CM Secure Browser (Authorized) : 100,000+
# 📏 Smart Ruler ↔️ cm/inch measuring for homework! : 10,000+
# Ruler cm : 100,000+
# Length Converter: convert mm,cm,m, feet,yard,mile : 50,000+
# CM AppLock Fingerprint 2018 : 100,000+
# m, cm, mm to yard, feet, inch converter tool : 100,000+
# Calculator CM : 500+
# Inches to cm conversion : 10,000+
# Centimeter Ruler : 10,000+
# CM S Pen Add-on(ROOT) : 10,000+
# Ruler : 1,000,000+
# Ruler & Area Measurement (cm, inch) : 10,000+
# Inches to Centimeters : 100,000+
# Speed Test - WiFi / Cellular speed test : 1,000,000+
# cm to inches | centimeters to inches conversion : 5,000+
# In to cm : 10+
# Co Checker : 1,000+
# Remote | Fire TV | Android TV | KODI | CetusPlay : 1,000,000+
# Hercules CP Mobile : 1,000+
# Poke Genie - Safe IV Calculator : 1,000,000+
# IV Calc CP Calculator Toolkit : 10,000+
# gCMOB : 1,000,000+
# Ditto CP Calculator GO : 1,000+
# Evolve CP Calc. for PokemonGo : 10,000+
# Contents Provider(C.P.)Explorer : 100+
# Calcy IV : 1,000,000+
# Meu Calendário CP : 100+
# CQ Key : 100+
# Webmail web mobile app : 100,000+
# Battle Result Predictor for CR : 1,000,000+
# Deck Advisor for CR : 5,000,000+
# Card Creator for CR : 10,000,000+
# Deck Analyzer for CR : 100,000+
# Deck Simulator for CR : 10,000+
# Counter Deck Calculator for CR : 500,000+
# CR Calculator : 50,000+
# DCUO|CR Calculator Lite : 10,000+
# CR -Call Recorder : 100+
# JavaScript Editor CR : 5,000+
# Chest Tracker for Clash Royale : 5,000,000+
# Java Editor CR : 50,000+
# XML Editor CR : 5,000+
# CR Tracker for Chests : 50+
# Helper for CS:GO : 10,000+
# CT - DTC Lookup : 10,000+
# Simpli CT : 100+
# Remote CT - Smart Remote : 1,000,000+
# HTC Transfer Tool : 5,000,000+
# Free CV Creator : 10,000+
# CV maker for Job Applications and Resume Maker : 10,000+
# CV Maker for Job Applications:Photo Resume Builder : 10,000+
# Easy Resume Builder, Resume help, Curriculum vitae : 50,000+
# Resume Maker / CV creator & Templates : 5,000+
# My CW : 100+
# Morse Notifier Free : 1,000+
# Cx File Explorer : 10,000+
# CX Ram Booster : 500+
# Secret Codes For Android : 500,000+
# ABTO CY-ET1 : 100+
# CZ File Manager : 1,000,000+
# HTC Sense Input - CZ : 10,000+
# CZ Kompas : 10+
# What is my IP address : 500,000+
# Master for Minecraft(Pocket Edition)-Mod Launcher : 50,000,000+
# Translate: text & voice translator : 5,000,000+
# The Zueira's Voice : 1,000,000+
# Battery Calibration : 5,000,000+
# FVD - Free Video Downloader : 10,000,000+
# Download Manager for Android : 10,000,000+
# SQLite DB Reader : 50,000+
# DB Browser : 50,000+
# Sound Meter : 10,000,000+
# dB: Sound Meter Pro : 5,000+
# dB Sound Level Meter : 10,000+
# DB Sound Meter: Measure Noise Level- Decibel Meter : 10,000+
# Check DB Benchmark : 100+
# dB Meter - measure sound & noise level in Decibel : 10,000+
# DB LINK RGB : 500+
# DB TOS - Pocket Helper : 10,000+
# Patron DB : 5,000+
# Bowers & Wilkins DB Subwoofers : 10,000+
# dB Sound Meter : 5,000+
# Preferences Manager and SQLite DB Viewer : 1,000+
# SW-DB : 10,000+
# DC Universe Online Map : 50,000+
# Vote 4 DC : 1,000+
# APUS File Manager (Explorer) : 50,000,000+
# Easy Language Translator : 10,000,000+
# Satellite Director : 10,000,000+
# df : 1,000+
# Digital Falak : 50,000+
# DF-CAM : 100+
# DF Wall Plus – Droid Firewall : 500+
# DF SmartPlus : 10+
# ProconLegis-DF : 5+
# Consultar Infracciones de Transito DF y Mexico : 10+
# PDF Reader – PDF Editor 2018 : 500,000+
# DG Smart life : 1,000+
# Roland DG Mobile Panel : 1,000+
# DG-App : 500+
# Digoo·Cloud : 10,000+
# DiskDigger photo recovery : 50,000,000+
# Automatic Call Recorder : 100,000,000+
# Virtual DJ Mixer : 100,000+
# Mix Virtual DJ 2018 : 100,000+
# Advanced Download Manager : 10,000,000+
# GetThemAll Any File Downloader : 5,000,000+
# Downloader & Private Browser : 50,000,000+
# Download All Files : 10,000,000+
# Download Accelerator Plus : 1,000,000+
# Download Manager : 10,000,000+
# Fast Download Manager : 1,000,000+
# Turbo Download Manager (and Browser) : 5,000,000+
# Download Blazer : 5,000,000+
# Download Manager For Android Free : 100,000+
# Turbo Downloader : 5,000,000+
# Advanced Download Manager Holo : 1,000,000+
# G-Download Manager : 50,000+
# TorrDroid - Torrent Downloader : 1,000,000+
# Download Manager - File & Video : 1,000,000+
# DM airdisk : 1,000+
# DM HiDisk : 5,000+
# DM airdisk Pro : 1,000+
# DM security - Dragon Mobile : 1,000+
# DM 24/7 : 1,000+
# DM AirDisk HDD : 100+
# DM AirDisk NAS : 50+
# File Viewer for Android : 1,000,000+
# EasyNote Notepad | To Do List : 1,000,000+
# Download Instant DP (Full HD) : 100,000+
# DQ Akses : 1+
# Anti-virus Dr.Web Light : 100,000,000+
# dr.fone - Recovery & Transfer wirelessly & Backup : 5,000,000+
# Dr. Battery - Fast Charger - Super Cleaner 2018 : 1,000,000+
# Dr. Safety - Antivirus, Booster, Cleaner, AppLock : 10,000,000+
# Dr.Web Security Space : 10,000,000+
# Dr. Booster - Boost Game Speed : 10,000,000+
# DS finder : 500,000+
# DS get : 5,000,000+
# DS cloud : 500,000+
# DS router : 50,000+
# DS Creator 2.0 : 500+
# DS App Manager : 1,000+
# DS Connector 2.0 : 500+
# NDS-controller : 1,000+
# Deep Sleep Battery Saver : 1,000,000+
# DS Flashlight : 10,000+
# DT Smart : 1,000+
# DT Baby Cam : 500+
# DT future1 cam : 50+
# WhatsVPN - Unlimited Free VPN : 500,000+
# Cache Cleaner-DU Speed Booster (booster & cleaner) : 100,000,000+
# DU Battery Saver - Battery Charger & Battery Life : 100,000,000+
# DU Antivirus Security - Applock & Privacy Guard : 10,000,000+
# DU Cleaner – Memory cleaner & clean phone cache : 10,000,000+
# DU Security : 100,000+
# DU Browser Mini(Small&Fast) : 1,000,000+
# Lock Screen - DU Locker & Lock screen wallpaper : 100,000+
# DU Emoji Keyboard（Simeji） : 500,000+
# DU Flashlight - Brightest LED & Flashlight Free : 5,000,000+
# Upgrade for Android DU Master : 1,000,000+
# GO Security－AntiVirus, AppLock, Booster : 10,000,000+
# AKASO DV : 10,000+
# Selfie DV : 1,000+
# SDV Cam : 10,000+
# DV Portfolio : 50+
# DV - Digito Verificador : 500+
# SportCAM : 100,000+
# DW VMAX : 100,000+
# DW Contacts Wear : 5,000+
# Digi Dex for DW Next Order @PS4 : 10,000+
# DW Timer : 100+
# DW Uninstall Applications : 10+
# DW Cleaner : 500+
# DW Missed call cleaner patch : 5,000+
# KeePass DX : 5,000+
# DX Spots Free : 1,000+
# DX Alert : 1,000+
# MBU DX Cluster : 500+
# edp re:dy : 10,000+
# edp re:dy smarthome : 5,000+
# Hidden Camera Detector : 10,000+
# 3G/4G Config Dz : 100,000+
# Files To SD Card Pro : 100,000+
# My Ooredoo Algeria : 100,000+
# DZ sim : 10,000+
# 3G to 4G Converter - Simulator : 10,000+
# Dz Camera : 10+
# Bihar Land Records - RoR and EB Quick Pay : 1,000+
# TNEB Reading : 10,000+
# Tamilnadu Electricity Info : 10,000+
# Punjab Online - Land Records • EB Bill Pay • RC/DL : 5,000+
# energyly (TNEB,BESCOM,MH,DL..) : 10,000+
# TN Patta, Chitta, EC : 100,000+
# TN Patta Chitta EC Info : 100,000+
# Barry EC : 1,000+
# Walk Freely (Ec Shlire) : 1,000+
# EC Apps List : 100+
# Victoria EC : 500+
# EC Designer 2.0 : 50+
# Kiamichi EC : 1,000+
# HOLSTON EC : 1,000+
# Marítimo EC : 10+
# EF Utilities : 5+
# EG Movi : 1,000+
# Energenie EG-PM1W Setup Wizard : 1,000+
# qEG APP / Química EG SRL : 10+
# VITEK EH DVR Viewer (Pro) : 10,000+
# EH kontrollrakendus : 5,000+
# Ei Electronics AudioLINK : 10,000+
# Code on the egg : 10,000+
# EI Calculator : 100+
# Verdant EI : 50+
# ei Calc : 10+
# Painel EJ SSH - INTERNET GRÁTIS : 50+
# Alex Fuel Calculator for EK : 500+
# Sanu Ek Pal Chain - Raid : 500+
# SIM Card Info : 1,000,000+
# The translator : 1,000,000+
# Instabridge - Free WiFi Passwords and Hotspots : 10,000,000+
# Keyboard ManMan : 10,000,000+
# HTC Sense Input - EN : 5,000,000+
# Bluetooth Pair : 1,000,000+
# ep-liggare - Elektronisk personalliggare : 100+
# Tester EP : 100+
# EP Kalkulator el. energije : 100+
# ES App Locker : 1,000,000+
# ES File Explorer : 100,000+
# ES Dark Theme for free : 1,000,000+
# ES Classic Theme : 1,000,000+
# ES Holo Theme : 500,000+
# ES File Explorer & Manager, Locker Xplorer 2018 : 1,000+
# ES Summer Chill Theme for Free : 100,000+
# OpenGL ES Extensions - The OpenGL Utility : 50,000+
# File Ex - ES File Explorer : 1,000+
# OpenGL ES CapsViewer : 10,000+
# OpenGL-ES Info : 10,000+
# Dr. ES PV Calculator : 500+
# ES File Explorer & File Manager 2018 : 5,000+
# HTC Sense Input - ES : 1,000,000+
# 2019 Tricks Es File Explores : 1,000+
# RAR : 50,000,000+
# File Manager by Xiaomi: release file storage space : 10,000,000+
# Moto File Manager : 10,000,000+
# Epson iPrint : 10,000,000+
# Schengen/EU App : 1,000+
# HondaLink EV : 10,000+
# EV Finder : 1,000+
# Texas Hold'em EV Calculator : 1,000+
# EV Calculator : 1,000+
# Mee-EW : 5+
# EW Widgets for Zooper : 100+
# EW Neuron Scan : 10+
# EdiRange : 100,000+
# Ex Explorer : Dual view exproler / file manager : 50,000+
# Papyrus Ex : 100,000+
# Fuel Calculator for EY : 1,000+
# Third Eye : 1,000,000+
# Hey That's Pretty Good! : 10,000+
# EZ Cleaner - Booster Optimizer : 500,000+
# EZ Bluetooth : 50,000+
# EZ-GUI Ground Station : 50,000+
# E-Z App™ Train Control : 1,000+
# EZ App Installer : 100,000+
# EZ Pass : 5,000+
# EZ-VPNGate : 5,000+
# EZ LED : 1,000+
# EZ Screenshot : 5,000+
# EZ Utilities Extension : 5,000+
# EZ-Placard - Free Placard Calculator : 1,000+
# HTC Sense Input - FA : 100,000+
# Farsi Keyboard : 1,000,000+
# Authy 2-Factor Authentication : 1,000,000+
# Flash Light on Call & SMS : 1,000,000+
# Mini for fb lite : 100,000+
# Video Downloader For FB: Save FB Videos 2018 : 50,000+
# Video Download For FB : 100,000+
# Video Downloader for FB : 5,000+
# Download Facebook Photo Albums : 100,000+
# FD Shift Calendar Widget : 100,000+
# FD CANNECT : 1+
# FE Connect : 5,000+
# FE IP : 1,000+
# FE Connect Fhoton : 100+
# FG On-The-Go : 1,000+
# FG Finder : 10,000+
# FH CODE : 100+
# My Truck : 10,000+
# Signal Info : 10,000+
# Signal Spy - Monitor Signal Strength & Data Usage : 100,000+
# LG Hi-Fi Plus Manager : 10,000+
# [root] Pry-Fi : 500,000+
# Wi-Fi settings shortcut : 50,000+
# Wi-Fi Master : 500,000+
# Wi-Fi Visualizer : 50,000+
# HD Wallpaper - Toyota FJ Cruiser : 100+
# FJ WiFi HDD : 5,000+
# FJ-link : 10+
# FK Crvena Zvezda Izzy : 50,000+
# Florida 511 : 50,000+
# Lottery Ticket Checker - Florida Results & Lotto : 500+
# Calculator Fn : 500+
# Fo File Manager : 100,000+
# Fon WiFi App – WiFi Connect : 50,000+
# MOD-MASTER for Minecraft PE (Pocket Edition) Free : 10,000,000+
# Draw with FP sDraw : 100,000+
# Fingerprint Quick Action : 1,000,000+
# FP Opgaver : 1,000+
# Finger Scanner Gestures : 100,000+
# FreedomPop Friends for Free Data : 5,000+
# Fisher-Price® Smart Connect™ : 50,000+
# Fingerprint Lock Screen Prank : 1,000,000+
# FP NFC Rewrite : 1,000+
# FreedomPop Diagnostics : 100,000+
# ChopAssistant : 50,000+
# Reindeer VPN - Proxy VPN : 100,000+
# Inf VPN - Global Proxy & Unlimited Free WIFI VPN : 1,000,000+
# FR Roster : 5,000+
# My FR App : 100+
# HTC Sense Input - FR : 100,000+

# %%
for app in android_free:
    if app[1] == 'BOOKS_AND_REFERENCE':
        print(app[0], ':', app[5])
# Out:
# E-Book Read - Read Book for free : 50,000+
# Download free book with green book : 100,000+
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Free Panda Radio Music : 100,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# English Grammar Complete Handbook : 500,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# Google Play Books : 1,000,000,000+
# AlReader -any text book reader : 5,000,000+
# Offline English Dictionary : 100,000+
# Offline: English to Tagalog Dictionary : 500,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# Recipes of Prophetic Medicine for free : 500,000+
# ReadEra – free ebook reader : 1,000,000+
# Anonymous caller detection : 10,000+
# Ebook Reader : 5,000,000+
# Litnet - E-books : 100,000+
# Read books online : 5,000,000+
# English to Urdu Dictionary : 500,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# English Persian Dictionary : 500,000+
# Flybook : 500,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# English translation from Bengali : 100,000+
# Pdf Book Download - Read Pdf Book : 100,000+
# Free Book Reader : 100,000+
# eBoox new: Reader for fb2 epub zip books : 50,000+
# Only 30 days in English, the guideline is guaranteed : 500,000+
# Moon+ Reader : 10,000,000+
# SH-02J Owner's Manual (Android 8.0) : 50,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Azpen eReader : 500,000+
# URBANO V 02 instruction manual : 100,000+
# Bible : 100,000,000+
# C Programs and Reference : 50,000+
# C Offline Tutorial : 1,000+
# C Programs Handbook : 50,000+
# Amazon Kindle : 100,000,000+
# Aab e Hayat Full Novel : 100,000+
# Aldiko Book Reader : 10,000,000+
# Google I/O 2018 : 500,000+
# R Language Reference Guide : 10,000+
# Learn R Programming Full : 5,000+
# R Programing Offline Tutorial : 1,000+
# Guide for R Programming : 5+
# Learn R Programming : 10+
# R Quick Reference Big Data : 1,000+
# V Made : 100,000+
# Wattpad 📖 Free Books : 100,000,000+
# Dictionary - WordWeb : 5,000,000+
# Guide (for X-MEN) : 100,000+
# AC Air condition Troubleshoot,Repair,Maintenance : 5,000+
# AE Bulletins : 1,000+
# Ae Allah na Dai (Rasa) : 10,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Ag PhD Field Guide : 10,000+
# Ag PhD Deficiencies : 10,000+
# Ag PhD Planting Population Calculator : 1,000+
# Ag PhD Soybean Diseases : 1,000+
# Fertilizer Removal By Crop : 50,000+
# A-J Media Vault : 50+
# Al-Quran (Free) : 10,000,000+
# Al Quran (Tafsir & by Word) : 500,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al-Muhaffiz : 50,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Al-Quran 30 Juz free copies : 500,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Surah Al-Waqiah : 100,000+
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000+
# Satellite AR : 1,000,000+
# Audiobooks from Audible : 100,000,000+
# Kinot & Eichah for Tisha B'Av : 10,000+
# AW Tozer Devotionals - Daily : 5,000+
# Tozer Devotional -Series 1 : 1,000+
# The Pursuit of God : 1,000+
# AY Sing : 5,000+
# Ay Hasnain k Nana Milad Naat : 10,000+
# Ay Mohabbat Teri Khatir Novel : 10,000+
# Arizona Statutes, ARS (AZ Law) : 1,000+
# Oxford A-Z of English Usage : 1,000,000+
# BD Fishpedia : 1,000+
# BD All Sim Offer : 10,000+
# Youboox - Livres, BD et magazines : 500,000+
# B&H Kids AR : 10,000+
# B y H Niños ES : 5,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# Borneo Bible, BM Bible : 10,000+
# MOD Black for BM : 100+
# BM Box : 1,000+
# Anime Mod for BM : 100+
# NOOK: Read eBooks & Magazines : 10,000,000+
# NOOK Audiobooks : 500,000+
# NOOK App for NOOK Devices : 500,000+
# Browsery by Barnes & Noble : 5,000+
# bp e-store : 1,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# BR Ambedkar Biography & Quotes : 10,000+
# BU Alsace : 100+
# Catholic La Bu Zo Kam : 500+
# Khrifa Hla Bu (Solfa) : 10+
# Kristian Hla Bu : 10,000+
# SA HLA BU : 1,000+
# Learn SAP BW : 500+
# Learn SAP BW on HANA : 500+
# CA Laws 2018 (California Laws and Codes) : 5,000+
# Bootable Methods(USB-CD-DVD) : 10,000+
# cloudLibrary : 100,000+
# SDA Collegiate Quarterly : 500+
# Sabbath School : 100,000+
# Cypress College Library : 100+
# Stats Royale for Clash Royale : 1,000,000+
# GATE 21 years CS Papers(2011-2018 Solved) : 50+
# Learn CT Scan Of Head : 5,000+
# Easy Cv maker 2018 : 10,000+
# How to Write CV : 100,000+
# CW Nuclear : 1,000+
# CY Spray nozzle : 10+
# BibleRead En Cy Zh Yue : 5+
# CZ-Help : 5+
# Modlitební knížka CZ : 500+
# Guide for DB Xenoverse : 10,000+
# Guide for DB Xenoverse 2 : 10,000+
# Guide for IMS DB : 10+
# DC HSEMA : 5,000+
# DC Public Library : 1,000+
# Painting Lulu DC Super Friends : 1,000+
# Dictionary : 10,000,000+
# Fix Error Google Playstore : 1,000+
# D. H. Lawrence Poems FREE : 1,000+
# Bilingual Dictionary Audio App : 5,000+
# DM Screen : 10,000+
# wikiHow: how to do anything : 1,000,000+
# Dr. Doug's Tips : 1,000+
# Bible du Semeur-BDS (French) : 50,000+
# La citadelle du musulman : 50,000+
# DV 2019 Entry Guide : 10,000+
# DV 2019 - EDV Photo & Form : 50,000+
# DV 2018 Winners Guide : 1,000+
# EB Annual Meetings : 1,000+
# EC - AP & Telangana : 5,000+
# TN Patta Citta & EC : 10,000+
# AP Stamps and Registration : 10,000+
# CompactiMa EC pH Calibration : 100+
# EGW Writings 2 : 100,000+
# EGW Writings : 1,000,000+
# Bible with EGW Comments : 100,000+
# My Little Pony AR Guide : 1,000,000+
# SDA Sabbath School Quarterly : 500,000+
# Duaa Ek Ibaadat : 5,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+
# EP Research Service : 1,000+
# Hymnes et Louanges : 100,000+
# EU Charter : 1,000+
# EU Data Protection : 1,000+
# EU IP Codes : 100+
# EW PDF : 5+
# BakaReader EX : 100,000+
# EZ Quran : 50,000+
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000+
# La Fe de Jesus : 1,000+
# La Fe de Jesús : 500+
# Le Fe de Jesus : 500+
# Florida - Pocket Brainbook : 1,000+
# Florida Statutes (FL Code) : 1,000+
# English To Shona Dictionary : 10,000+
# Greek Bible FP (Audio) : 1,000+
# Golden Dictionary (FR-AR) : 500,000+
# Fanfic-FR : 5,000+
# Bulgarian French Dictionary Fr : 10,000+
# Chemin (fr) : 1,000+
# The SCP Foundation DB fr nn5n : 1,000+

# %%
for app in android_free:
    if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000+'
                                            or app[5] == '5,000,000+'
                                            or app[5] == '10,000,000+'
                                            or app[5] == '50,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# AlReader -any text book reader : 5,000,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# ReadEra – free ebook reader : 1,000,000+
# Ebook Reader : 5,000,000+
# Read books online : 5,000,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# Moon+ Reader : 10,000,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Aldiko Book Reader : 10,000,000+
# Dictionary - WordWeb : 5,000,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Al-Quran (Free) : 10,000,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Satellite AR : 1,000,000+
# Oxford A-Z of English Usage : 1,000,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# NOOK: Read eBooks & Magazines : 10,000,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# Stats Royale for Clash Royale : 1,000,000+
# Dictionary : 10,000,000+
# wikiHow: how to do anything : 1,000,000+
# EGW Writings : 1,000,000+
# My Little Pony AR Guide : 1,000,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+

# %%
for app in android_free:
    if app[1] == 'TOOLS' and (app[5] == '1,000,000+'
                                            or app[5] == '5,000,000+'
                                            or app[5] == '10,000,000+'
                                            or app[5] == '50,000,000+'):
        print(app[0], ':', app[5])
# Out:
# Moto Display : 10,000,000+
# Motorola Alert : 50,000,000+
# Motorola Assist : 50,000,000+
# Moto Suggestions ™ : 1,000,000+
# Moto Voice : 10,000,000+
# myMetro : 10,000,000+
# File Manager : 50,000,000+
# My Telcel : 50,000,000+
# Calculator - free calculator, multi calculator app : 10,000,000+
# ASUS Sound Recorder : 10,000,000+
# iWnn IME for Nexus : 5,000,000+
# Samsung Max - Data Savings & Privacy Protection : 10,000,000+
# Android TV Remote Service : 1,000,000+
# ZenUI Help : 10,000,000+
# ZenUI Keyboard – Emoji, Theme : 10,000,000+
# Files Go by Google: Free up space on your phone : 10,000,000+
# SD card backup : 1,000,000+
# Nokia mobile support : 5,000,000+
# File Manager -- Take Command of Your Files Easily : 10,000,000+
# Clear : 10,000,000+
# Phone : 10,000,000+
# HTC Lock Screen : 10,000,000+
# AT&T Smart Wi-Fi : 10,000,000+
# Google app for Android TV : 10,000,000+
# Sound Recorder: Recorder & Voice Changer Free : 10,000,000+
# Remote Link (PC Remote) : 10,000,000+
# HTC Sense Input : 10,000,000+
# App vault : 10,000,000+
# TouchPal Keyboard for vivo : 1,000,000+
# My love : 10,000,000+
# DuraSpeed : 10,000,000+
# Digital Alarm Clock : 10,000,000+
# Alarm Clock Free : 10,000,000+
# Puzzle Alarm Clock ⏰ : 1,000,000+
# Alarm Clock : 5,000,000+
# I Can't Wake Up! Alarm Clock : 1,000,000+
# High-Powered Flashlight : 10,000,000+
# Brightest Flashlight - LED Light : 50,000,000+
# LED Flashlight : 10,000,000+
# Flashlight & LED Torch : 10,000,000+
# Color Flashlight : 50,000,000+
# CM Flashlight (Compass, SOS) : 5,000,000+
# Flashlight HD LED : 50,000,000+
# Flashlight - Torch LED Light : 10,000,000+
# Super Flashlight + LED : 5,000,000+
# Brightest LED Flashlight : 5,000,000+
# Brightest Flashlight Free ® : 50,000,000+
# Fraction Calculator Plus Free : 5,000,000+
# Calculator Plus Free : 10,000,000+
# CALCU™ Stylish Calculator Free : 5,000,000+
# Mobi Calculator free & AD free! : 5,000,000+
# Calculator with Percent (Free) : 1,000,000+
# Graphing Calculator : 1,000,000+
# Unit Converter : 1,000,000+
# Calculator ++ : 1,000,000+
# MyScript Calculator : 10,000,000+
# ConvertPad - Unit Converter : 10,000,000+
# Unit Converter Pro : 1,000,000+
# Classic Calculator : 5,000,000+
# Scientific Calculator Free : 1,000,000+
# Age Calculator : 1,000,000+
# SuperVPN Free VPN Client : 50,000,000+
# Hideman VPN : 5,000,000+
# Fast Secure VPN : 1,000,000+
# Free & Premium VPN - FinchVPN : 1,000,000+
# Hotspot Shield Free VPN Proxy & Wi-Fi Security : 50,000,000+
# OpenVPN Connect – Fast & Safe SSL VPN Client : 10,000,000+
# VPN - Fast, Secure & Unlimited WiFi with VyprVPN : 1,000,000+
# FREEDOME VPN Unlimited anonymous Wifi Security : 1,000,000+
# SurfEasy Secure Android VPN : 5,000,000+
# TunnelBear VPN : 5,000,000+
# VPN Free - Betternet Hotspot VPN & Private Browser : 10,000,000+
# Smart Keyboard Trial : 10,000,000+
# Emoji keyboard - Cute Emoticons, GIF, Stickers : 50,000,000+
# Google Handwriting Input : 10,000,000+
# Wifi Analyzer : 10,000,000+
# Network Signal Info : 1,000,000+
# osmino Wi-Fi: free WiFi : 10,000,000+
# WiFi Overview 360 : 1,000,000+
# Speedcheck : 1,000,000+
# Internet Speed Meter Lite : 10,000,000+
# Wifi Inspector : 5,000,000+
# WiFi Automatic : 1,000,000+
# NETGEAR WiFi Analytics : 1,000,000+
# Keypad Lock Screen : 10,000,000+
# photo keypad lockscreen : 10,000,000+
# Solo Locker (DIY Locker) : 10,000,000+
# Lock Screen : 1,000,000+
# ZERO Lock Screen : 1,000,000+
# AppLock - Fingerprint : 10,000,000+
# Smart AppLock (App Protect) : 10,000,000+
# Screen Off and Lock : 10,000,000+
# Screen Lock : 1,000,000+
# Flashlight : 10,000,000+
# Screen Lock - with Fingerprint Simulator : 10,000,000+
# Tuner - gStrings Free : 10,000,000+
# Video Downloader for Facebook : 50,000,000+
# HSPA+ Tweaker (3G booster) : 5,000,000+
# Force LTE Only : 1,000,000+
# Mobile Number Tracker : 5,000,000+
# I Screen Dialer : 1,000,000+
# Smart TV Remote : 10,000,000+
# O Launcher 8.0 for Android™ O Oreo Launcher : 1,000,000+
# QR Code Reader : 50,000,000+
# S Player - Lightest and Most Powerful Video Player : 1,000,000+
# S S9 Launcher - Galaxy S8/S9 Launcher, theme, cool : 1,000,000+
# T-Mobile : 10,000,000+
# T-Mobile Visual Voicemail : 50,000,000+
# AT&T FamilyMap® : 10,000,000+
# Don't touch my phone : 5,000,000+
# WIFI WPS WPA TESTER : 10,000,000+
# App Lock: Locker w/ fingerprint, Parental Control : 1,000,000+
# Open in WhatsApp (click to chat) : 1,000,000+
# WPSApp : 10,000,000+
# X-VPN - Free Unlimited VPN Proxy : 5,000,000+
# Phone X Launcher, OS 11 iLauncher & Control Center : 5,000,000+
# X-plore File Manager : 10,000,000+
# Flashlight X : 1,000,000+
# iSwipe Phone X : 1,000,000+
# [ROOT] X Privacy Installer : 1,000,000+
# Antivirus & Mobile Security : 10,000,000+
# Flashlight Ultimate : 1,000,000+
# ZArchiver : 10,000,000+
# Zapya - File Transfer, Sharing : 10,000,000+
# CPU-Z : 10,000,000+
# Moto Z Market : 1,000,000+
# Universal AC Remote Control : 1,000,000+
# Air conditioner remote control : 1,000,000+
# A/C Air Conditioner Remote : 1,000,000+
# A/C Universal Remote Control : 1,000,000+
# Mi Remote controller - for TV, STB, AC and more : 10,000,000+
# AC & TV, DVD, Set Top Box - Remote control IR : 1,000,000+
# AppBrain Ad Detector : 1,000,000+
# Adguard Content Blocker : 1,000,000+
# Anti Adware : 1,000,000+
# Photo Compress 2.0 - Ad Free : 1,000,000+
# AppFinder by AppTap : 5,000,000+
# APN Settings : 1,000,000+
# QR BARCODE SCANNER : 10,000,000+
# Image 2 Wallpaper : 5,000,000+
# LG AV REMOTE : 1,000,000+
# Norton Security and Antivirus : 10,000,000+
# Kaspersky Mobile Antivirus: AppLock & Web Security : 50,000,000+
# Bitdefender Antivirus Free : 1,000,000+
# Avast Cleanup & Boost, Phone Cleaner, Optimizer : 10,000,000+
# Display Phone Screen On TV : 1,000,000+
# Remote for Sony TV & Sony Blu-Ray Players MyAV : 1,000,000+
# Unseen - No Last Seen : 5,000,000+
# All Language Translator : 5,000,000+
# BQ Services : 1,000,000+
# Software Update : 1,000,000+
# Free antivirus and VPN : 1,000,000+
# Simple Gallery : 1,000,000+
# BTNotification : 5,000,000+
# BT Notifier : 1,000,000+
# BT Controller : 1,000,000+
# Mediatek SmartDevice : 1,000,000+
# Battery Notifier BT Free : 1,000,000+
# Bixby Button Remapper - bxActions : 1,000,000+
# Limbo PC Emulator QEMU ARM x86 : 1,000,000+
# Project Fi by Google : 1,000,000+
# Bubble : 5,000,000+
# CA DMV : 1,000,000+
# CCleaner : 50,000,000+
# Terminal Emulator for Android : 10,000,000+
# Clean Master Lite - For Low-End Phone : 50,000,000+
# CM Security Open VPN - Free, fast unlimited proxy : 1,000,000+
# CM Security Lite - Antivirus : 10,000,000+
# AppLock - Fingerprint Unlock : 5,000,000+
# Speed Booster - Ram, Battery & Game Speed Booster : 1,000,000+
# CM FILE MANAGER : 50,000,000+
# Ruler : 1,000,000+
# Speed Test - WiFi / Cellular speed test : 1,000,000+
# Remote | Fire TV | Android TV | KODI | CetusPlay : 1,000,000+
# Poke Genie - Safe IV Calculator : 1,000,000+
# gCMOB : 1,000,000+
# Calcy IV : 1,000,000+
# Battle Result Predictor for CR : 1,000,000+
# Deck Advisor for CR : 5,000,000+
# Card Creator for CR : 10,000,000+
# Chest Tracker for Clash Royale : 5,000,000+
# Remote CT - Smart Remote : 1,000,000+
# HTC Transfer Tool : 5,000,000+
# CZ File Manager : 1,000,000+
# Master for Minecraft(Pocket Edition)-Mod Launcher : 50,000,000+
# Translate: text & voice translator : 5,000,000+
# The Zueira's Voice : 1,000,000+
# Battery Calibration : 5,000,000+
# FVD - Free Video Downloader : 10,000,000+
# Download Manager for Android : 10,000,000+
# Sound Meter : 10,000,000+
# APUS File Manager (Explorer) : 50,000,000+
# Easy Language Translator : 10,000,000+
# Satellite Director : 10,000,000+
# DiskDigger photo recovery : 50,000,000+
# Advanced Download Manager : 10,000,000+
# GetThemAll Any File Downloader : 5,000,000+
# Downloader & Private Browser : 50,000,000+
# Download All Files : 10,000,000+
# Download Accelerator Plus : 1,000,000+
# Download Manager : 10,000,000+
# Fast Download Manager : 1,000,000+
# Turbo Download Manager (and Browser) : 5,000,000+
# Download Blazer : 5,000,000+
# Turbo Downloader : 5,000,000+
# Advanced Download Manager Holo : 1,000,000+
# TorrDroid - Torrent Downloader : 1,000,000+
# Download Manager - File & Video : 1,000,000+
# File Viewer for Android : 1,000,000+
# EasyNote Notepad | To Do List : 1,000,000+
# dr.fone - Recovery & Transfer wirelessly & Backup : 5,000,000+
# Dr. Battery - Fast Charger - Super Cleaner 2018 : 1,000,000+
# Dr. Safety - Antivirus, Booster, Cleaner, AppLock : 10,000,000+
# Dr.Web Security Space : 10,000,000+
# Dr. Booster - Boost Game Speed : 10,000,000+
# DS get : 5,000,000+
# Deep Sleep Battery Saver : 1,000,000+
# DU Antivirus Security - Applock & Privacy Guard : 10,000,000+
# DU Cleaner – Memory cleaner & clean phone cache : 10,000,000+
# DU Browser Mini(Small&Fast) : 1,000,000+
# DU Flashlight - Brightest LED & Flashlight Free : 5,000,000+
# Upgrade for Android DU Master : 1,000,000+
# GO Security－AntiVirus, AppLock, Booster : 10,000,000+
# SIM Card Info : 1,000,000+
# The translator : 1,000,000+
# Instabridge - Free WiFi Passwords and Hotspots : 10,000,000+
# Keyboard ManMan : 10,000,000+
# HTC Sense Input - EN : 5,000,000+
# Bluetooth Pair : 1,000,000+
# ES App Locker : 1,000,000+
# ES Dark Theme for free : 1,000,000+
# ES Classic Theme : 1,000,000+
# HTC Sense Input - ES : 1,000,000+
# RAR : 50,000,000+
# File Manager by Xiaomi: release file storage space : 10,000,000+
# Moto File Manager : 10,000,000+
# Epson iPrint : 10,000,000+
# Third Eye : 1,000,000+
# Farsi Keyboard : 1,000,000+
# Authy 2-Factor Authentication : 1,000,000+
# Flash Light on Call & SMS : 1,000,000+
# MOD-MASTER for Minecraft PE (Pocket Edition) Free : 10,000,000+
# Fingerprint Quick Action : 1,000,000+
# Fingerprint Lock Screen Prank : 1,000,000+
# Inf VPN - Global Proxy & Unlimited Free WIFI VPN : 1,000,000+

# %% [markdown]
# We see similar patterns from the Appstore.
# In the top 5 install categories, there are some huge apps with 1 billion installs and a smaller group with 50-100 million installs. It is difficult to compete with such applications, most often there are huge and complex products behind them.
#
# In my opinion good categories for free apps now are:
# - Games (Family in Google Store). Although this is an overheated category, it still has a demand. People spend a lot of time there, and simple games are often played by kids who spend a lot of time in the app one way or another.
# - Tools. There is a demand for them, there are many small applications with 1 million installs, and it is easier to compete there, although they do not spend much time in such applications.
# - Books. There is a demand for a book app as well as for book readers, people spend a lot of time in such apps (reading a book is not a 10 minute task) and creating such an app is not that difficult a task.

# %% [markdown]
# We also notice there are quite a few apps built around the book Quran, which suggests that building an app around a popular book can be profitable. It seems that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets.

# %% [markdown]
# ## Conclusions
#
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
